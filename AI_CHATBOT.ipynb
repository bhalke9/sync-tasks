# %%
import json
import string
import random
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
data = {"intents": [

             {"tag": "age",
              "patterns": ["how old are you?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey","sup","Heya","Dude"],
              "responses": ["Hi there", "Hello", "Hi :)"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?"],
              "responses": ["I have no name yet," "You can give me one, and I will appreciate it"]
             },
             {"tag": "questions",
              "patterns": ["admin","main","first block","old block"],
              "responses": ["Bharadwaja block is known as admin block. All the room numbers start with 1. It is the first ever created block of our college"]
             },
             {"tag": "AAT",
              "patterns": ["concept videos","techtalk"],
              "responses": ["AAT videos counts for semester end results.They can be selected from Samvidha->AAT Selection->subject"]
             },
             {"tag": "exams",
              "patterns": ["exams","semester","mids",'externals'],
              "responses": ["for every semester two mid term exams are conducted along with final semester end, the weightage goes as follows:70(SEE)+20(CIE)+10(AAT)"]
             }

]}
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 128)               3712
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 12,423
# Trainable params: 12,423
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 0s 388ms/step - loss: 1.9241 - accuracy: 0.1905
# Epoch 2/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8317 - accuracy: 0.3810
# Epoch 3/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7777 - accuracy: 0.4286
# Epoch 4/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6064 - accuracy: 0.6667
# Epoch 5/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5983 - accuracy: 0.5714
# Epoch 6/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4446 - accuracy: 0.6667
# Epoch 7/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3812 - accuracy: 0.5238
# Epoch 8/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2678 - accuracy: 0.6190
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1909 - accuracy: 0.6667
# Epoch 10/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9706 - accuracy: 0.8095
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8973 - accuracy: 0.7619
# Epoch 12/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8428 - accuracy: 0.7619
# Epoch 13/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8040 - accuracy: 0.7619
# Epoch 14/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7446 - accuracy: 0.8095
# Epoch 15/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6549 - accuracy: 0.7619
# Epoch 16/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3787 - accuracy: 0.9524
# Epoch 17/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4125 - accuracy: 0.9048
# Epoch 18/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2552 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2333 - accuracy: 0.9524
# Epoch 20/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2761 - accuracy: 0.9524
# Epoch 21/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1422 - accuracy: 0.9524
# Epoch 22/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0997 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1328 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0898 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0890 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0741 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1243 - accuracy: 0.9524
# Epoch 28/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.2771e-04 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.3744e-04 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.6949e-04 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.4974e-04 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0534 - accuracy: 0.9524
# Epoch 62/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.5669e-04 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8724e-04 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.9258e-04 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7998e-04 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.9929e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.3115e-04 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7417e-04 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 6ms/step - loss: 6.6668e-04 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2670e-04 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 6ms/step - loss: 7.5408e-04 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4154e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9166e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3206e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6332e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7890e-04 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.8433e-04 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1696e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3224e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4494e-04 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8580e-04 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.3050e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9344e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5370e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7024e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 20ms/step - loss: 4.4056e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.2352e-04 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2006e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7413e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.1886e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1314e-04 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9853e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1310e-05 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1933e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9954e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.4936e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1792e-05 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.4102e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0566e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8509e-04 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8087e-04 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6635e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3608e-05 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8619e-04 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 6ms/step - loss: 8.9723e-04 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3580e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5454e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.3562e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.1016e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7517e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8284e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4966e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9272e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9331e-04 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 5ms/step - loss: 4.3892e-05 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8224e-04 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1150e-04 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3629e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7030e-05 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5755e-04 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7908e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 6ms/step - loss: 7.4039e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2942e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0477e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9308e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.5647e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6428e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.8433e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9087e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2692e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 6ms/step - loss: 4.8193e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7298e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5532e-04 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.4336e-04 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6966e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6709e-04 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3595e-04 - accuracy: 1.0000

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["intents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
while True:
    newMessage = input("")
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, data)
    
    print(ourResult)
# Out:
# what about exams
# 1/1 [==============================] - 0s 47ms/step
# for every semester two mid term exams are conducted along with final semester end, the weightage goes as follows:70(SEE)+20(CIE)+10(AAT)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c4d0274a5379> in <module>
#       1 while True:
# ----> 2     newMessage = input("")
#       3     intents = Pclass(newMessage, newWords, ourClasses)
#       4     ourResult = getRes(intents, data)
#       5
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
